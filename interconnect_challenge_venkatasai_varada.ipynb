# %%
import pyarrow
import pandas as pd

def read_input(path):
    return pd.read_feather(path)


import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.feature_extraction.text import _VectorizerMixin
from sklearn.feature_selection._base import SelectorMixin
from sklearn.feature_selection import SelectKBest
from sklearn.feature_extraction.text import CountVectorizer


def get_feature_out(estimator, feature_in):
    if hasattr(estimator,'get_feature_names'):
        if isinstance(estimator, _VectorizerMixin):
            return [f'vec_{f}' \
                for f in estimator.get_feature_names()]
        else:
            return estimator.get_feature_names(feature_in)
    elif isinstance(estimator, SelectorMixin):
        return np.array(feature_in)[estimator.get_support()]
    else:
        return feature_in

def get_ct_feature_names(ct):

    output_features = []

    for name, estimator, features in ct.transformers_:
        if name!='remainder':
            if isinstance(estimator, Pipeline):
                current_features = features
                for step in estimator:
                    current_features = get_feature_out(step, current_features)
                features_out = current_features
            else:
                features_out = get_feature_out(estimator, features)
            output_features.extend(features_out)
        elif estimator=='passthrough':
            output_features.extend(ct._feature_names_in[features])
                
    return output_features

ic_summary = read_input('/Users/vnk/Downloads/Algorithms_Challenge/interconnect_roi_summary.feather')
ic_time_Series = read_input('/Users/vnk/Downloads/Algorithms_Challenge/interconnect_roi_timeseries.feather')

# %%
 ic_summary
# Out:
#                            filename       roi_id cell_group roi_side polarity  \
# 0                    Rec-000013.ats     1-A-left        1-A     left      pos
# 1                    Rec-000013.ats   1-A-center        1-A   center      neg
# 2                    Rec-000013.ats    1-A-right        1-A    right      pos
# 3                    Rec-000013.ats     1-B-left        1-B     left      pos
# 4                    Rec-000013.ats   1-B-center        1-B   center      neg
# ...                             ...          ...        ...      ...      ...
# 5827  SM05326_LOW_WELD_TEST1 L2.ats  18-K-center       18-K   center      neg
# 5828  SM05326_LOW_WELD_TEST1 L2.ats   18-K-right       18-K    right      pos
# 5829  SM05326_LOW_WELD_TEST1 L2.ats    18-L-left       18-L     left      pos
# 5830  SM05326_LOW_WELD_TEST1 L2.ats  18-L-center       18-L   center      neg
# 5831  SM05326_LOW_WELD_TEST1 L2.ats   18-L-right       18-L    right      pos
#
#             delta result failure_type
# 0      355.550000   pass         None
# 1      452.953125   pass         None
# 2      520.587500   pass         None
# 3     1105.310000   pass         None
# 4      378.309375   pass         None
# ...           ...    ...          ...
# 5827   125.312500   pass         None
# 5828   123.255000   pass         None
# 5829   162.072500   pass         None
# 5830   162.143750   pass         None
# 5831   193.325000   pass         None
#
# [5832 rows x 8 columns]

# %%
ic_summary['failure_type'].isna().sum()
# Out:
# 5808

# %%
ic_summary['failure_type'].value_counts()
# Out:
# hot     17
# cold     7
# Name: failure_type, dtype: int64

# %%
ic_time_Series
# Out:
#                               filename  frame_number       roi_id cell_group  \
# 0                       Rec-000013.ats             1     1-A-left        1-A
# 1                       Rec-000013.ats             1   1-A-center        1-A
# 2                       Rec-000013.ats             1    1-A-right        1-A
# 3                       Rec-000013.ats             1     1-B-left        1-B
# 4                       Rec-000013.ats             1   1-B-center        1-B
# ...                                ...           ...          ...        ...
# 1122331  SM05326_LOW_WELD_TEST1 L2.ats           111  18-K-center       18-K
# 1122332  SM05326_LOW_WELD_TEST1 L2.ats           111   18-K-right       18-K
# 1122333  SM05326_LOW_WELD_TEST1 L2.ats           111    18-L-left       18-L
# 1122334  SM05326_LOW_WELD_TEST1 L2.ats           111  18-L-center       18-L
# 1122335  SM05326_LOW_WELD_TEST1 L2.ats           111   18-L-right       18-L
#
#         roi_side polarity  mean_pixel_value
# 0           left      pos       7695.830000
# 1         center      neg       7649.421875
# 2          right      pos       7610.145000
# 3           left      pos       7661.817500
# 4         center      neg       7616.990625
# ...          ...      ...               ...
# 1122331   center      neg       4863.853125
# 1122332    right      pos       4895.822500
# 1122333     left      pos       4973.267500
# 1122334   center      neg       5047.671875
# 1122335    right      pos       5134.522500
#
# [1122336 rows x 7 columns]

# %%
ic_time_Series[(ic_time_Series['filename']=='Rec-000013.ats') & (ic_time_Series['roi_id']=='1-A-left')]
# Out:
#               filename  frame_number    roi_id cell_group roi_side polarity  \
# 0       Rec-000013.ats             1  1-A-left        1-A     left      pos
# 648     Rec-000013.ats             2  1-A-left        1-A     left      pos
# 1296    Rec-000013.ats             3  1-A-left        1-A     left      pos
# 1944    Rec-000013.ats             4  1-A-left        1-A     left      pos
# 2592    Rec-000013.ats             5  1-A-left        1-A     left      pos
# ...                ...           ...       ...        ...      ...      ...
# 169128  Rec-000013.ats           262  1-A-left        1-A     left      pos
# 169776  Rec-000013.ats           263  1-A-left        1-A     left      pos
# 170424  Rec-000013.ats           264  1-A-left        1-A     left      pos
# 171072  Rec-000013.ats           265  1-A-left        1-A     left      pos
# 171720  Rec-000013.ats           266  1-A-left        1-A     left      pos
#
#         mean_pixel_value
# 0              7695.8300
# 648            7695.9050
# 1296           7695.1800
# 1944           7695.2675
# 2592           7695.1000
# ...                  ...
# 169128         8044.1300
# 169776         8045.8250
# 170424         8046.2025
# 171072         8047.3050
# 171720         8049.1800
#
# [266 rows x 7 columns]

# %%
ic_pixel_stats = ic_time_Series.groupby(['filename','roi_id'])['mean_pixel_value'].agg(['mean', 'min', 'max']).reset_index()
ic_pixel_stats
# Out:
#                              filename      roi_id         mean          min  \
# 0                      Rec-000008.ats  1-A-center  7933.512168  7723.878125
# 1                      Rec-000008.ats    1-A-left  7968.288913  7768.455000
# 2                      Rec-000008.ats   1-A-right  7933.090085  7678.012500
# 3                      Rec-000008.ats  1-B-center  7974.438904  7710.450000
# 4                      Rec-000008.ats    1-B-left  8269.168768  7737.327500
# ...                               ...         ...          ...          ...
# 5827  SM05334_ HIGH_WELD_TEST2 L2.ats    9-K-left  5117.541448  5042.880000
# 5828  SM05334_ HIGH_WELD_TEST2 L2.ats   9-K-right  5159.873571  5081.945000
# 5829  SM05334_ HIGH_WELD_TEST2 L2.ats  9-L-center  5569.356672  5517.350000
# 5830  SM05334_ HIGH_WELD_TEST2 L2.ats    9-L-left  5396.543472  5321.217500
# 5831  SM05334_ HIGH_WELD_TEST2 L2.ats   9-L-right  5847.276488  5770.642500
#
#               max
# 0     8257.512500
# 1     8290.990000
# 2     8325.817500
# 3     8393.971875
# 4     9180.202500
# ...           ...
# 5827  5185.680000
# 5828  5227.600000
# 5829  5618.493750
# 5830  5464.030000
# 5831  5917.270000
#
# [5832 rows x 5 columns]

# %%
ic = ic_summary.merge(ic_pixel_stats, on = ['filename','roi_id'], how = 'inner')
ic['failure_type'] = ic['failure_type'].fillna('just_right')
ic[['cell_group_column','cell_group_row']] = ic.cell_group.str.split('-',expand=True)

# %%
features = ic[['cell_group_column','cell_group_row','roi_side','polarity','delta','mean','min','max']]

# %%
features.dtypes
# Out:
# cell_group_column     object
# cell_group_row        object
# roi_side              object
# polarity              object
# delta                float64
# mean                 float64
# min                  float64
# max                  float64
# dtype: object

# %%
Y = ic['failure_type']
Y.value_counts()
# Out:
# just_right    5808
# hot             17
# cold             7
# Name: failure_type, dtype: int64

# %%
import numpy as np
from sklearn.pipeline import Pipeline

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, Y, test_size=0.20, random_state=42)

# %%
y_train.shape
# Out:
# (4665,)

# %%
numeric_features = x_train.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = x_train.select_dtypes(exclude=[np.number]).columns.tolist()

numeric_transformer = Pipeline(steps=[('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(drop='first'))])
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)],
    remainder="drop")

# %%
preprocessor_fit = preprocessor.fit(x_train)
data = preprocessor_fit.transform(x_train)

# %%
test_data = preprocessor_fit.transform(x_test)

# %%
test_data.shape
# Out:
# (1167, 35)

# %%
from sklearn.linear_model import LogisticRegression
class_weight={'cold':0.4,'hot':0.5, 'just_right':0.1}

model = LogisticRegression(multi_class='multinomial', solver='lbfgs', class_weight = 'balanced')
model.fit(data,y_train)
# Out:
# LogisticRegression(class_weight='balanced', multi_class='multinomial')

# %%
from sklearn.model_selection import GridSearchCV
class_weight1={'cold':0.4,'hot':0.5, 'just_right':0.1}
class_weight2={'cold':0.4,'hot':0.4, 'just_right':0.2}


parameters = {'class_weight':(class_weight1, class_weight2)}
model = LogisticRegression(multi_class='multinomial')

model = GridSearchCV(model, parameters, cv =5)
model.fit(data,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(multi_class='multinomial'),
#              param_grid={'class_weight': ({'cold': 0.4, 'hot': 0.5,
#                                            'just_right': 0.1},
#                                           {'cold': 0.4, 'hot': 0.4,
#                                            'just_right': 0.2})})

# %%
model.cv_results_
# Out:
# {'mean_fit_time': array([0.05317578, 0.04578509]),
#  'std_fit_time': array([0.0121176 , 0.00217317]),
#  'mean_score_time': array([0.00079141, 0.0006916 ]),
#  'std_score_time': array([1.27584160e-04, 2.72053882e-05]),
#  'param_class_weight': masked_array(data=[{'cold': 0.4, 'hot': 0.5, 'just_right': 0.1},
#                     {'cold': 0.4, 'hot': 0.4, 'just_right': 0.2}],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'class_weight': {'cold': 0.4, 'hot': 0.5, 'just_right': 0.1}},
#   {'class_weight': {'cold': 0.4, 'hot': 0.4, 'just_right': 0.2}}],
#  'split0_test_score': array([0.99571275, 0.99571275]),
#  'split1_test_score': array([0.99678457, 0.99678457]),
#  'split2_test_score': array([0.99571275, 0.99571275]),
#  'split3_test_score': array([0.99678457, 0.99678457]),
#  'split4_test_score': array([0.98928189, 0.99464094]),
#  'mean_test_score': array([0.99485531, 0.99592712]),
#  'std_test_score': array([0.00282763, 0.00080207]),
#  'rank_test_score': array([2, 1], dtype=int32)}

# %%
y_predict = model.predict(test_data)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#         cold       0.00      0.00      0.00         1
#          hot       0.00      0.00      0.00         2
#   just_right       1.00      1.00      1.00      1164
#
#     accuracy                           1.00      1167
#    macro avg       0.33      0.33      0.33      1167
# weighted avg       0.99      1.00      1.00      1167
# /Users/vnk/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
ic['cell_group'].nunique()
# Out:
# 216

# %%
ic_time_Series.filename.unique()
# Out:
# array(['Rec-000013.ats', 'Rec-000012.ats', 'Rec-000010.ats',
#        'Rec-000011.ats', 'Rec-000008.ats', 'Rec-000009.ats',
#        'SM05334_ HIGH_WELD_TEST2 L2.ats',
#        'SM05330_ HIGH_WELD_TEST2 L2.ats', 'SM05326_LOW_WELD_TEST1 L2.ats'],
#       dtype=object)

# %%
ic_summary.failure_type.value_counts()
# Out:
# hot     17
# cold     7
# Name: failure_type, dtype: int64

# %%
ic_summary[ic_summary['result']=='fail']
# Out:
#                              filename       roi_id cell_group roi_side  \
# 163                    Rec-000013.ats   5-G-center        5-G   center
# 200                    Rec-000013.ats    6-G-right        6-G    right
# 226                    Rec-000013.ats   7-D-center        7-D   center
# 3888  SM05334_ HIGH_WELD_TEST2 L2.ats     1-A-left        1-A     left
# 3889  SM05334_ HIGH_WELD_TEST2 L2.ats   1-A-center        1-A   center
# 3892  SM05334_ HIGH_WELD_TEST2 L2.ats   1-B-center        1-B   center
# 4536  SM05330_ HIGH_WELD_TEST2 L2.ats     1-A-left        1-A     left
# 4540  SM05330_ HIGH_WELD_TEST2 L2.ats   1-B-center        1-B   center
# 4541  SM05330_ HIGH_WELD_TEST2 L2.ats    1-B-right        1-B    right
# 4543  SM05330_ HIGH_WELD_TEST2 L2.ats   1-C-center        1-C   center
# 4546  SM05330_ HIGH_WELD_TEST2 L2.ats   1-D-center        1-D   center
# 4551  SM05330_ HIGH_WELD_TEST2 L2.ats     1-F-left        1-F     left
# 4561  SM05330_ HIGH_WELD_TEST2 L2.ats   1-I-center        1-I   center
# 4573  SM05330_ HIGH_WELD_TEST2 L2.ats   2-A-center        2-A   center
# 4602  SM05330_ HIGH_WELD_TEST2 L2.ats     2-K-left        2-K     left
# 4681  SM05330_ HIGH_WELD_TEST2 L2.ats   5-A-center        5-A   center
# 4753  SM05330_ HIGH_WELD_TEST2 L2.ats   7-A-center        7-A   center
# 4756  SM05330_ HIGH_WELD_TEST2 L2.ats   7-B-center        7-B   center
# 4757  SM05330_ HIGH_WELD_TEST2 L2.ats    7-B-right        7-B    right
# 4759  SM05330_ HIGH_WELD_TEST2 L2.ats   7-C-center        7-C   center
# 4978  SM05330_ HIGH_WELD_TEST2 L2.ats  13-D-center       13-D   center
# 5236    SM05326_LOW_WELD_TEST1 L2.ats   2-F-center        2-F   center
# 5245    SM05326_LOW_WELD_TEST1 L2.ats   2-I-center        2-I   center
# 5704    SM05326_LOW_WELD_TEST1 L2.ats  15-F-center       15-F   center
#
#      polarity        delta result failure_type
# 163       neg   382.928125   fail          hot
# 200       pos    31.622500   fail         cold
# 226       neg   493.690625   fail          hot
# 3888      pos    40.327500   fail         cold
# 3889      neg   304.462500   fail          hot
# 3892      neg   431.909375   fail          hot
# 4536      pos    30.320000   fail         cold
# 4540      neg  1160.465625   fail          hot
# 4541      pos    37.490000   fail         cold
# 4543      neg   378.728125   fail          hot
# 4546      neg   360.715625   fail          hot
# 4551      pos    21.945000   fail         cold
# 4561      neg   465.256250   fail          hot
# 4573      neg   380.043750   fail          hot
# 4602      pos    27.002500   fail         cold
# 4681      neg   585.428125   fail          hot
# 4753      neg   552.309375   fail          hot
# 4756      neg  1876.671875   fail          hot
# 4757      pos    58.975000   fail         cold
# 4759      neg   398.728125   fail          hot
# 4978      neg   275.181250   fail          hot
# 5236      neg   403.671875   fail          hot
# 5245      neg   214.262500   fail          hot
# 5704      neg   143.640625   fail          hot

# %%
ic_summary['failure_type'].isna().sum()
# Out:
# 5808

# %%
ic_summary
# Out:
#                            filename       roi_id cell_group roi_side polarity  \
# 0                    Rec-000013.ats     1-A-left        1-A     left      pos
# 1                    Rec-000013.ats   1-A-center        1-A   center      neg
# 2                    Rec-000013.ats    1-A-right        1-A    right      pos
# 3                    Rec-000013.ats     1-B-left        1-B     left      pos
# 4                    Rec-000013.ats   1-B-center        1-B   center      neg
# ...                             ...          ...        ...      ...      ...
# 5827  SM05326_LOW_WELD_TEST1 L2.ats  18-K-center       18-K   center      neg
# 5828  SM05326_LOW_WELD_TEST1 L2.ats   18-K-right       18-K    right      pos
# 5829  SM05326_LOW_WELD_TEST1 L2.ats    18-L-left       18-L     left      pos
# 5830  SM05326_LOW_WELD_TEST1 L2.ats  18-L-center       18-L   center      neg
# 5831  SM05326_LOW_WELD_TEST1 L2.ats   18-L-right       18-L    right      pos
#
#             delta result failure_type
# 0      355.550000   pass         None
# 1      452.953125   pass         None
# 2      520.587500   pass         None
# 3     1105.310000   pass         None
# 4      378.309375   pass         None
# ...           ...    ...          ...
# 5827   125.312500   pass         None
# 5828   123.255000   pass         None
# 5829   162.072500   pass         None
# 5830   162.143750   pass         None
# 5831   193.325000   pass         None
#
# [5832 rows x 8 columns]
